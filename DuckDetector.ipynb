# %% [markdown]
# <a href="https://colab.research.google.com/github/kbearden89/cosc325/blob/main/DuckDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install fiftyone
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 69.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 942.7/942.7 kB 43.2 MB/s eta 0:00:00
# ...

# %%
#import fiftyone as fo
#dataset = fo.zoo.load_zoo_dataset(
 #             "open-images-v7",
  #            split="test",
   #           label_types=["detections", "segmentations", "points"],
    #          classes=["Duck"],
     #         only_matching=False,
      #        max_samples=1000,
       #       shuffle=True
        #  )

# %%
# !unzip "/content/drive/MyDrive/Ducks/Duck Detection.v1i.yolov9.zip" -d "/content/"
# Out:
# Archive:  /content/drive/MyDrive/Ducks/Duck Detection.v1i.yolov9.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/011022_duck_1600_jpg.rf.0587e9e40c235273a20605c709291115.jpg
#  extracting: /content/test/images/013_89c3d319_jpg.rf.65d68a4dee1b91b46f3bbd3d7b35aafd.jpg
#  extracting: /content/test/images/030_25267718_jpg.rf.7df23bdd96bf08514fd237830ea96b78.jpg
#  extracting: /content/test/images/0NEAA28QT95M_jpg.rf.e0d59dcb0bdb81a16883eaae25fc11d7.jpg
#  extracting: /content/test/images/0PTN4HDR41UY_jpg.rf.d7aa4b740180851267af4306402200f8.jpg
#  extracting: /content/test/images/105_a15151e3_jpg.rf.0f0dcb409c4979624611d332b44acee0.jpg
#  extracting: /content/test/images/107_93ed53ba_jpg.rf.ba5a58ec88643b88d6ca26e30ec7051b.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.2/872.2 kB 44.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.train(data="/content/data.yaml", epochs=50)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 175MB/s]
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
am_i_a_duck = model("https://upload.wikimedia.org/wikipedia/commons/b/bf/Anas_platyrhynchos_male_female_quadrat.jpg")
import matplotlib.pyplot as plt
plt.imshow(am_i_a_duck[0].plot())
plt.title("Yolo results")
plt.show()
# Out:
# ...
# 100%|██████████| 4.54M/4.54M [00:00<00:00, 31.0MB/s]
# image 1/1 /content/Anas_platyrhynchos_male_female_quadrat.jpg: 640x640 3 Ducks, 7.5ms
# Speed: 3.7ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
am_i_a_duck = model("https://upload.wikimedia.org/wikipedia/commons/9/99/Elon_Musk_Colorado_2022_%28cropped2%29.jpg")
import matplotlib.pyplot as plt
plt.imshow(am_i_a_duck[0].plot())
plt.title("Yolo results")
plt.show()
# Out:
# ...
# 100%|██████████| 351k/351k [00:00<00:00, 37.2MB/s]
# image 1/1 /content/Elon_Musk_Colorado_2022_(cropped2).jpg: 640x512 1 Duck, 41.1ms
# Speed: 2.6ms preprocess, 41.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)

# %%
am_i_a_duck = model("/content/roommate.JPG")
import matplotlib.pyplot as plt
plt.imshow(am_i_a_duck[0].plot())
plt.title("Yolo results")
plt.show()
# Out:
# image 1/1 /content/roommate.JPG: 640x480 4 Ducks, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
